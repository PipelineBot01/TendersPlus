# %%
import sys  
sys.path.append('../../../')
sys.path.append('../../../Model')

# %%
from Model.researcher.update.researcher_updater import ResearcherUpdater
from db.loadjson import get_data

# %%
test_df = get_data()
test_df.rename(columns={'field_id': 'division', 'name': 'tag'}, inplace=True)

# %%
test_df
# Out:
#                      email                      university  \
# 0           123@anu.edu.au          University of Canberra
# 1                  1@1.com        Charles Sturt University
# 2                  1@a.com  Australian National University
# 3                  a@a.com  Australian National University
# 4                a@anu.com  Australian National University
# 5                  a@b.com          University of Canberra
# 6                 aa@a.com          University of Canberra
# 7              anu@anu.com  Australian National University
# 8                b@anu.com        Charles Sturt University
# 9          blank@blank.com  Australian National University
# 10  carl.carla@hotmail.com  Australian National University
# 11        Ryanyang@anu.com          University of Canberra
# 12           test2@anu.com  Australian National University
# 13           test3@anu.com  Australian National University
# 14           test@test.com  Australian National University
# ...

# %%
test_df[['email', 'tag']].explode('tag')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13608/1167367160.py in <module>
# ----> 1 test_df[['email', 'tag']].explode('tag')
#
# c:\users\24966\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# c:\users\24966\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...

# %%
input_df = rup.reg_info

# %%
input_df['id'] = 'Reg_'+ input_df['email']

# %%
input_df['field_id'].tolist()
# Out:
# ['ENVIRONMENTAL',
#  'EARTH',
#  'INFORMATION AND COMPUTING',
#  'TECHNOLOGY',
#  'EARTH',
#  'ENVIRONMENTAL',
#  'BIOLOGICAL',
#  'EARTH',
#  'ENVIRONMENTAL',
#  'PSYCHOLOGY AND COGNITIVE SCIENCES',
#  'CHEMICAL',
#  'BIOLOGICAL',
#  'AGRICULTURAL AND VETERINARY',
#  'EARTH',
#  'ENVIRONMENTAL',
#  'MATHEMATICAL',
#  'CHEMICAL',
#  'EARTH',
#  'PHYSICAL',
#  'CHEMICAL',
#  'LAW AND LEGAL STUDIES',
#  'EARTH',
#  'MATHEMATICAL',
#  'INFORMATION AND COMPUTING',
#  'PSYCHOLOGY AND COGNITIVE SCIENCES',
#  'LANGUAGE, COMMUNICATION AND CULTURE',
#  'HISTORY AND ARCHAEOLOGY',
#  'PHILOSOPHY AND RELIGIOUS STUDIES',
#  'EARTH',
#  'LANGUAGE, COMMUNICATION AND CULTURE',
#  'PHILOSOPHY AND RELIGIOUS STUDIES',
#  'COMMERCE, MANAGEMENT, TOURISM AND SERVICES',
#  'LANGUAGE, COMMUNICATION AND CULTURE',
#  'PHILOSOPHY AND RELIGIOUS STUDIES',
#  'EARTH',
#  'INFORMATION AND COMPUTING',
#  'INFORMATION AND COMPUTING',
#  'INFORMATION AND COMPUTING',
#  'BIOLOGICAL',
#  'INFORMATION AND COMPUTING',
# ...
