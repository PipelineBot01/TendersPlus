# %%
import pandas as pd
import re

# %%
input_data = pd.read_csv('test_result.csv')

# %%
def get_list(row):
    return row.split(',')

# %%
input_data['tmp'] = input_data['reco'].map(get_list)

# %%
new_df = input_data.explode('tmp')

# %%
def get_list(row):
    value  =row.split(':')
    value[0]

# %%
new_df['value'] = input_data['tmp'].map(get_list)
# Out:
#          data                                            profile  \
# 0   2022.4.30  {id:"jennytestone@test.com",divisions:["Commer...
# 0   2022.4.30  {id:"jennytestone@test.com",divisions:["Commer...
# 0   2022.4.30  {id:"jennytestone@test.com",divisions:["Commer...
# 0   2022.4.30  {id:"jennytestone@test.com",divisions:["Commer...
# 0   2022.4.30  {id:"jennytestone@test.com",divisions:["Commer...
# ..        ...                                                ...
# 7    2022/5/7  {"id":StageZero@anu.edu.au, "divisions": ["MED...
# 7    2022/5/7  {"id":StageZero@anu.edu.au, "divisions": ["MED...
# 7    2022/5/7  {"id":StageZero@anu.edu.au, "divisions": ["MED...
# 7    2022/5/7  {"id":StageZero@anu.edu.au, "divisions": ["MED...
# 7    2022/5/7  {"id":StageZero@anu.edu.au, "divisions": ["MED...
#
#                                                   ref  \
# 0                                                 NaN
# 0                                                 NaN
# ...
